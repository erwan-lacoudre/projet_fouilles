# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('cleaned_music.csv', index_col=0)

# %%
df.head()
# Out:
#                         Title             Artist            Top Genre  Year  \
# Index
# 1                     Sunrise        Norah Jones      adult standards  2004
# 2                 Black Night        Deep Purple           album rock  2000
# 3              Clint Eastwood           Gorillaz  alternative hip hop  2001
# 4               The Pretender       Foo Fighters    alternative metal  2007
# 5      Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#        Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# Index
# 1                         157      30            53            -14        11
# 2                         135      79            50            -11        17
# 3                         168      69            66             -9         7
# 4                         173      96            43             -4         3
# 5                         106      82            58             -5        10
#
# ...

# %%
sns.set(style="whitegrid")
sns.swarmplot(x='Length (Duration)', hue="Rock", data=df, size=2,
              palette={0:'b', 1:'g'})
# Out:
# <AxesSubplot:xlabel='Length (Duration)'>

# %%
sns.set(style="whitegrid")
sns.swarmplot(x='Length (Duration)', hue='Year', data=df, size=2)
# Out:
# <AxesSubplot:xlabel='Length (Duration)'>

# %%
nb_songs = df.shape[0]
tx = [sum(df['Rock'])/nb_songs, sum(df['Pop'])/nb_songs, sum(df['Standards'])/nb_songs, sum(df['Metal'])/nb_songs, sum(df['Indie'])/nb_songs, sum(df['Cabaret'])/nb_songs,
sum(df['Soul'])/nb_songs, sum(df['Wave'])/nb_songs, sum(df['Invasion'])/nb_songs, sum(df['Hip-hop'])/nb_songs]
tx_pop = sum(df['Pop'])/nb_songs
tx_std = sum(df['Standards'])/nb_songs
tx_rock = sum(df['Rock'])/nb_songs
tx_rock = sum(df['Rock'])/nb_songs
tx_rock = sum(df['Rock'])/nb_songs
tx_rock = sum(df['Rock'])/nb_songs
tx_rock = sum(df['Rock'])/nb_songs
df
# Out:
#                         Title             Artist            Top Genre  Year  \
# Index
# 1                     Sunrise        Norah Jones      adult standards  2004
# 2                 Black Night        Deep Purple           album rock  2000
# 3              Clint Eastwood           Gorillaz  alternative hip hop  2001
# 4               The Pretender       Foo Fighters    alternative metal  2007
# 5      Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
# ...                       ...                ...                  ...   ...
# 1989               Summertime    Louis Armstrong      adult standards  1958
# 1990         Heartbreak Hotel      Elvis Presley      adult standards  1958
# 1991                Hound Dog      Elvis Presley      adult standards  1958
# 1992          Johnny B. Goode        Chuck Berry           blues rock  1959
# 1994           Blueberry Hill        Fats Domino      adult standards  1959
#
# ...
